# %%
# %matplotlib inline

import numpy as np
from enum import Enum
import matplotlib.pyplot as plt

# %%
class Strategie(Enum):
    CHANGER = 1
    GARDER = 0

# %%
def play_game(strategie):
    portes = [0, 1, 2]
    
    bonne_porte = np.random.rand(0,2)
    
    premier_choix =  randint(0,2)
    
    portes.remove(premier_choix)
    
    if premier_choix == bonne_porte:
        portes.remove(portes[randint(0,1)])
    else:
        portes = [bonne_porte]
        
    dc = 0 
    if (strategie == Strategie.GARDER):
        dc = premier_choix
    else: 
        dc = portes[0]
    return dc == bonne_porte

# %%
play_game(Strategie.CHANGER)
# Out:
# True

# %%
def play(strategie, nb_tours):
    return [1 if play_game(strategie) else 0 for i in range(nb_tours)]

# %%
sum(play(Strategie.GARDER, 1000))
# Out:
# 330

# %%
plt.plot(play(Strategie.GARDER, 20))

# %%
plt.plot(play(Strategie.CHANGER, 20))

# %%
plt.bar([1,2], [sum(play(Strategie.GARDER, 1000)), sum(play(Strategie.CHANGER, 1000))], tick_label=["GARDER","CHANGER"])
# Out:
# <BarContainer object of 2 artists>

# %%
gains_changer = []
gains_garder = []
samples =  [1000, 10000, 20000, 50000, 80000, 100000]
for tours in samples:
    gains_changer.append(play(Strategie.CHANGER, tours))
    gains_garder.append(play(Strategie.GARDER, tours))

# %%
plt.plot(play(Strategie.CHANGER, 20))

# %%
figure = plt.figure()

plot = plt.scatter(samples, [sum(x) for x in gains_changer])

plot = plt.scatter(samples, [sum(x) for x in gains_garder])

# %%
m_g = sum(play(Strategie.GARDER, 1000))/1000

# %%
m_g
# Out:
# 0.311

# %%
m_c =  sum(play(Strategie.CHANGER, 1000))/1000

# %%
m_c
# Out:
# 0.669

# %%
plt.bar([1,2], [(sum(play(Strategie.GARDER, 1000))/1000), (sum(play(Strategie.CHANGER, 1000))/1000)], tick_label=["mg","mc"])
# Out:
# <BarContainer object of 2 artists>
